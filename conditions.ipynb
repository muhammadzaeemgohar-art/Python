# %% [markdown]
# ## 📝 Challenge 01: Smart Grade Calculator ⭐⭐⭐
#
# **Task:** Write a grade classification program that inputs a student's score, validates that the score is within a realistic range, assigns a letter grade, and determines their overall pass/fail status.
#
# ---
#
# ### 📋 Requirements
#
# 1. **User Input:** Prompt the user to enter a numeric score (integer or float) between `0` and `100`.
# 2. **Data Validation:** Before performing any grade evaluation, check if the input is valid. If the score is **below 0** or **above 100**, reject it with an error message and terminate or skip calculation.
# 3. **Grading Logic:** Assign a letter grade based on the following scale:
#    * **90 – 100:** A
#    * **80 – 89:** B
#    * **70 – 79:** C
#    * **60 – 69:** D
#    * **Below 60:** F
# 4. **Status Check:** Determine the completion status. Any grade of **D or above is a Pass**, while a grade of **F is a Fail**.
# 5. **Output Formatting:** Print a clean report showing the student's score, their letter grade, and whether they passed or failed.
#
# ---
#
# ### 📥 Example Walkthrough
#
# #### Case A: Valid Entry (Pass)
# * **Input Score:** `78.5`
# * **Expected Output:**
#   ```text
#   Score: 78.50%
#   Grade: C
#   Status: PASSED
#   Error: Invalid score entered. Marks must be between 0 and 100.

# %%
marks=float(input("Enter your marks(0-100):"))
if marks>=0 and marks<=100:
    if marks>=90 and marks<=100:
        grade="A"
    elif marks>=80 and marks<=89:
        grade="B"
    elif marks>=70 and marks<=79:
        grade="C"
    elif marks>=60 and marks<=69:
        grade="D"
    elif marks<60:
        grade="F"
    if grade=="F":
        status="FAIL"
    else:
        status="PASSED"
    print(f"Score: {marks}")
    print(f"Grade: {grade}")
    print(f"Status: {status}")
else:
     print("Invalid score entered. Marks must be between 0 and 100.")

# %% [markdown]
# ## 📝 Challenge 02: ATM PIN Verification ⭐⭐⭐
#
# **Task:** Create a basic ATM system simulator that verifies a user's security PIN and processes cash withdrawals based on account balances and safety parameters.
#
# ---
#
# ### 📋 Requirements
#
# 1. **System Constants:** Pre-program a fixed, valid security PIN (e.g., `1234`) and establish a starting account balance of **Rs. 50,000**.
# 2. **User Input:** Prompt the user to enter two inputs:
#    * **Security PIN** (Integer)
#    * **Withdrawal Amount** (Float/Integer)
# 3. **Verification & Transaction Engine:**
#    * **PIN Validation:** Check the input PIN first. If it does not match your system constant, immediately print `"Access Denied"` and cancel the transaction.
#    * **Amount Validation:** If the PIN is correct, check the withdrawal amount. Reject any negative amounts (e.g., less than or equal to `0`).
#    * **Balance Validation:** Ensure the requested cash amount does not exceed the available account balance.
#      * If `withdrawal > balance`, print `"Insufficient Funds"`.
#      * If `withdrawal <= balance`, deduct the funds and approve the payout.
# 4. **Output Formatting:** For successful transactions, print a clean summary revealing the withdrawn sum and the remaining account balance.
#
# ---
#
# ### 📥 Example Walkthroughs
#
# #### Case A: Authentication Failure
# * **Input PIN:** `9999`
# * **Expected Output:**
# ```markdown
# Access Denied
# ========================================
#           TRANSACTION SUCCESS
# ========================================
# Withdrawn Amount:   Rs. 15,500.00
# Remaining Balance:  Rs. 34,500.00
# ========================================

# %%
sec_pin=1234
account_balance=50000
pin=int(input("Enter Security Pin:"))
if pin>=0:
    if pin==sec_pin:
        print(F"Login Successful")
        withdrawn_amount=int(input("Enter Amount of Money you want to Withdraw:"))
        if withdrawn_amount>0: 
            if account_balance>=withdrawn_amount:
                remaining_balance=account_balance-withdrawn_amount
                print(f"================================================")
                print(f"              TRANSACTION SUCCESS               ")
                print(f"================================================")
                print(f"Withdrawn Amount:     Rs. {withdrawn_amount}")
                print(f"Remaining Balance:    Rs. {remaining_balance}")
                print(f"================================================")
            else:
                print("Insufficent Balance.")
        else:
            print("Withdrawal amount must be greater than 0.Try Again.")
    else:
        print(f"Access Denied.Incorrect Password")
else:
    print("Invalid Format.Pin cannot be negative.")

# %% [markdown]
# ## 📝 Challenge 03: Age Eligibility Checker ⭐⭐⭐
#
# **Task:** Write a verification program that evaluates a user's age and nationality to determine their legal eligibility for critical identity documents and civic rights.
#
# ---
#
# ### 📋 Requirements
#
# 1. **User Inputs:** Prompt the user to provide two parameters:
#    * **Age** (Integer)
#    * **Nationality** (String, e.g., `"Pakistani"` or `"Other"`)
# 2. **Data Validation:** Validate the age input immediately. Reject any entry that is **less than 0** or physically unrealistic (e.g., above 120) with an appropriate error message.
# 3. **Eligibility Rules:** Evaluate the following documentation criteria:
#    * **CNIC:** Eligible if age is **18 or above**.
#    * **Voting Rights:** Eligible if age is **18 or above** AND nationality is **"Pakistani"**.
#    * **Driving License:** Eligible if age is **18 or above**.
#    * **Passport:** Eligible at **any age** (no minimum requirement).
# 4. **Output Formatting:** Print a clean checklist showing which items the user is currently eligible to apply for.
#
# ---
#
# ### 📥 Example Walkthroughs
#
# #### Case A: Pakistani Adult (Full Eligibility)
# * **Input Age:** `21`
# * **Input Nationality:** `Pakistani`
# * **Expected Output:**
# ```markdown
# ========================================
#        ELIGIBILITY REPORT CARD
# ========================================
# ✅ Eligible for Passport
# ✅ Eligible for CNIC
# ✅ Eligible for Driving License
# ✅ Eligible to Vote in Pakistan
# ========================================

# %%
age=int(input("Enter your age:"))
nationality=str(input("Enter your Nationality (Pakistani or Other):")).lower()
if (nationality=="pakistani" or nationality=="other") and age>=0 and age<=120:
    if age>=18 and nationality=="pakistani":
        cnic="Eligible"
        voting="Eligible"
        driving="Eligible"
    elif age>=18 and nationality=="other":
        cnic="Eligible"
        voting="Not Eligible"
        driving="Eligible"
    else:
        cnic="Not Eligible"
        voting="Not Eligible"
        driving="Not Eligible"
    print(f"==================================")
    print(f"       ELIGIBLITY REPORT CARD     ")
    print(f"==================================")
    print(f"{'Eligible'} for Passport.")
    print(f"{cnic} for CNIC.")
    print(f"{driving} for Driving License")
    print(f"{voting} for Voting in Pakistan")
    print(f"==================================")
else:
    print("Invalid Input.Incorrect Age or Nationality.")

# %% [markdown]
# ## 📝 Challenge 04: Income Tax Calculator ⭐⭐⭐
#
# **Task:** Create a tax assessment tool that calculates a user's progressive annual income tax bracket, computes the specific tax liabilities, and tracks the net take-home salary.
#
# ---
#
# ### 📋 Requirements
#
# 1. **User Input:** Prompt the user to enter their **Annual Salary** (Float/Integer).
# 2. **Data Validation:** Validate the input immediately. Reject any entry that is **less than 0** with an appropriate error message.
# 3. **Tax Bracket Margins:** Calculate the tax liability according to the following progressive rules:
#    * **Up to 500,000:** 0% tax
#    * **500,001 to 1,000,000:** 5% tax
#    * **1,000,001 to 2,000,000:** 10% tax
#    * **Above 2,000,000:** 15% tax
# 4. **Output Formatting:** Print a clean summary displaying the original salary, the corresponding tax percentage rate, the calculated tax amount, and the net salary remaining after tax. Round all numeric calculations to exactly **2 decimal places**.
#
# ---
#
# ### 📥 Example Walkthroughs
#
# #### Case A: Low-Income Bracket (Tax-Exempt)
# * **Input Salary:** `450000`
# * **Expected Output:**
# ```markdown
# ========================================
#              TAX STATEMENT
# ========================================
# Gross Salary:     Rs. 450,000.00
# Tax Rate Applied: 0%
# Tax Amount:       Rs. 0.00
# ----------------------------------------
# Net Salary:       Rs. 450,000.00
# ========================================

# %%
annual_salary=float(input("Enter Your Annual Salary:"))
if annual_salary>=0:
    if annual_salary<=500000:
        tax_rate=0
        tax_amount=0
        net_salary=annual_salary-tax_amount
    elif annual_salary>500000 and annual_salary<=1000000:
        tax_rate=5
        tax_amount=annual_salary*(5/100)
        net_salary=annual_salary-tax_amount
    elif annual_salary>1000000 and annual_salary<=2000000:
        tax_rate=10
        tax_amount=annual_salary*(10/100)
        net_salary=annual_salary-tax_amount
    elif annual_salary>2000000:
        tax_rate=15
        tax_amount=annual_salary*(15/100)
        net_salary=annual_salary-tax_amount
    print(f"==================================")
    print(f"          TAX STATEMENT           ")
    print(f"==================================")
    print(f"Gross Salary:     Rs. {annual_salary}")
    print(f"Tax Rate Applied: {tax_rate}%")
    print(f"Tax Amount:     Rs. {tax_amount}")
    print(f"----------------------------------")
    print(f"Net Salary:     Rs. {net_salary}")
    print(f"==================================")
else:
    print("Invalid Input.Reenter Salary")

# %% [markdown]
# ## 📝 Challenge 05: Student Scholarship Checker ⭐⭐⭐
#
# **Task:** Write a scholarship assessment tool that evaluates a student's CGPA and monthly family income against specific criteria to determine their eligibility for partial or full tuition waivers.
#
# ---
#
# ### 📋 Requirements
#
# 1. **User Inputs:** Prompt the user to enter two parameters:
#    * **CGPA** (Float, on a 4.0 scale)
#    * **Family Income** (Float/Integer)
# 2. **Data Validation:** Validate the inputs immediately. Reject the evaluation if:
#    * The CGPA is **less than 0 or greater than 4.0**.
#    * The Family Income is **less than 0**.
# 3. **Scholarship Tiers:** Evaluate eligibility using the following priority rules:
#    * **100% Scholarship:** CGPA $\ge$ 3.8 AND family income $<$ 80,000
#    * **75% Scholarship:** CGPA $\ge$ 3.5 AND family income $<$ 120,000
#    * **50% Scholarship:** CGPA $\ge$ 3.0 AND family income $<$ 180,000
#    * **Otherwise:** No scholarship awarded.
# 4. **Output Formatting:** Print a structured eligibility report showing the student's metrics and their finalized scholarship status.
#
# ---
#
# ### 📥 Example Walkthroughs
#
# #### Case A: Top Tier Merit & Financial Need
# * **Input CGPA:** `3.9`
# * **Input Income:** `75000`
# * **Expected Output:**
# ```markdown
# ========================================
#        SCHOLARSHIP ELIGIBILITY
# ========================================
# Student CGPA:  3.90
# Family Income: Rs. 75,000.00
# ----------------------------------------
# Status:        🎉 APPROVED
# Award:         100% Tuition Waiver
# ========================================

# %%
cgpa=float(input("Enter Your CGPA:"))
family_income=float(input("Enter Your Family Income:"))
if (cgpa>=0 and cgpa<=4) and family_income>=0:
    if cgpa>=3.8 and family_income<80000:
        status="Approved"
        waiver=100
    elif cgpa>=3.5 and family_income<120000:
        status="Approved"
        waiver=75
    elif cgpa>=3.0 and family_income<180000:
        status="Approved"
        waiver=50
    else:
        status="Not Approved"
        waiver=0
    print(f"===============================================")
    print(f"           SCHOLARSHIP ELIGIBILITY            ")
    print(f"===============================================")
    print(f"Student CGPA: {cgpa}")
    print(f"Family Income: Rs. {family_income:.2f}")
    print(f"-----------------------------------------------")
    print(f"Status:               {status}")
    print(f"Award:                {waiver}% Tuition Waiver")
    print(f"===============================================")
else:
    print("Invalid Input.Incorrect CGPA or Family Income.")

# %% [markdown]
# ## 📝 Challenge 06: E-commerce Discount System ⭐⭐⭐
#
# **Task:** Create a dynamic checkout pricing tool that evaluates a customer's total purchase amount and loyalty membership level to calculate precise discounts and a final net bill.
#
# ---
#
# ### 📋 Requirements
#
# 1. **User Inputs:** Prompt the user to provide two parameters:
#    * **Purchase Amount** (Float/Integer)
#    * **Membership Level** (String: `"Gold"`, `"Silver"`, or `"None"`)
# 2. **Data Validation:** Validate the purchase amount immediately. Reject any entry that is **less than or equal to 0** with an appropriate error message.
# 3. **Tiered Discount Engine:** Apply matching logic based on membership level and spending thresholds:
#    * **Gold Members:**
#      * Amount $>$ 50,000 $\rightarrow$ **20% discount**
#      * Otherwise $\rightarrow$ **10% discount**
#    * **Silver Members:**
#      * Amount $>$ 50,000 $\rightarrow$ **15% discount**
#      * Otherwise $\rightarrow$ **5% discount**
#    * **No Membership ("None"):**
#      * Amount $>$ 50,000 $\rightarrow$ **8% discount**
#      * Otherwise $\rightarrow$ **No discount (0%)**
# 4. **Output Formatting:** Print a clean invoice showing the initial purchase amount, the discount percentage/amount saved, and the final checkout price. Round all financial values to exactly **2 decimal places**.
#
# ---
#
# ### 📥 Example Walkthroughs
#
# #### Case A: Gold Tier High-Value Customer
# * **Input Amount:** `65000`
# * **Input Membership:** `Gold`
# * **Expected Output:**
# ```markdown
# ========================================
#            CHECKOUT SUMMARY
# ========================================
# Purchase Amount:    Rs. 65,000.00
# Membership Level:   Gold (20% Off)
# Discount Value:    -Rs. 13,000.00
# ----------------------------------------
# Final Amount:       Rs. 52,000.00
# ========================================

# %%
purchase_amount=float(input("Enter Purchase Amount:"))
membership_level=str(input("Enter Your Membership Level (Gold,Silver,None):")).lower()
if purchase_amount>=0 and (membership_level=="gold" or membership_level=="silver" or membership_level=="none"):
    if purchase_amount>=50000 and membership_level=="gold":
        discount_rate=20
        discount_amount=purchase_amount*(20/100)
        final_amount=purchase_amount-discount_amount
    elif purchase_amount<50000 and membership_level=="gold":
        discount_rate=10
        discount_amount=purchase_amount*(10/100)
        final_amount=purchase_amount-discount_amount
    elif purchase_amount>=50000 and membership_level=="silver":
        discount_rate=15
        discount_amount=purchase_amount*(15/100)
        final_amount=purchase_amount-discount_amount
    elif purchase_amount<50000 and membership_level=="silver":
        discount_rate=5
        discount_amount=purchase_amount*(5/100)
        final_amount=purchase_amount-discount_amount
    elif purchase_amount>=50000 and membership_level=="none":
        discount_rate=8
        discount_amount=purchase_amount*(8/100)
        final_amount=purchase_amount-discount_amount
    elif purchase_amount<50000 and membership_level=="none":
        discount_rate=5
        discount_amount=purchase_amount*(5/100)
        final_amount=purchase_amount-discount_amount
    membership_level=membership_level.capitalize()
    print(f"=================================================")
    print(f"               CHECKOUT SUMMARY                  ")
    print(f"=================================================")
    print(f"Purchase Amount:     Rs. {purchase_amount:.2f}")
    print(f"Membership Level:    {membership_level} ({discount_rate}% OFF)")
    print(f"Discount Value:     -Rs. {discount_amount:.2f}")
    print(f"-------------------------------------------------")
    print(f"Final Amount:        Rs. {final_amount:.2f}")
    print(f"=================================================")
else:
    print("Invalid Input.Incorrect Purchase Amount or Membership Level. ")

# %% [markdown]
# ## 📝 Challenge 07: Employee Bonus Calculator ⭐⭐⭐
#
# **Task:** Design a corporate payroll optimization program that evaluates an employee's tenure (years of experience) and annual performance evaluation rating to calculate their qualifying bonus percentage.
#
# ---
#
# ### 📋 Requirements
#
# 1. **User Inputs:** Prompt the user to enter two performance variables:
#    * **Years of Experience** (Integer/Float)
#    * **Performance Rating** (Integer, on a scale of 1 to 5)
# 2. **Data Validation:** Immediately inspect inputs for payroll compatibility. Reject the evaluation if:
#    * Years of experience is **less than 0**.
#    * Performance rating is **less than 1 or greater than 5**.
# 3. **Bonus Tier Architecture:** Evaluate incentives using the following hierarchy:
#    * **30% Bonus:** Experience $\ge$ 10 years AND Performance Rating $\ge$ 4
#    * **20% Bonus:** Experience $\ge$ 5 years AND Performance Rating $\ge$ 4
#    * **10% Bonus:** Experience $\ge$ 2 years AND Performance Rating $\ge$ 3
#    * **Otherwise:** No bonus allocated (0%).
# 4. **Output Formatting:** Print a professional HR assessment report containing the verified credentials and the final assigned bonus allocation.
#
# ---
#
# ### 📥 Example Walkthroughs
#
# #### Case A: Senior High-Performer
# * **Input Experience:** `12`
# * **Input Rating:** `5`
# * **Expected Output:**
# ```markdown
# ========================================
#          ANNUAL BONUS ASSESSMENT
# ========================================
# Tenure Assessed: 12.0 Years
# Performance Rank: 5/5
# ----------------------------------------
# Incentive Status: 🎖️ QUALIFIED
# Bonus Percentage: 30% Premium
# ========================================

# %%
years_experience=float(input("Enter Years of Experience:"))
performance_rating=int(input("Enter Performance Rating (1-5):"))
if (performance_rating<=5 and performance_rating>=1) and years_experience>=0:
    if years_experience>=10 and performance_rating>=4:
        bonus_percentage=30
        incentive_status="QUALIFIED"
    elif years_experience>=5 and performance_rating>=4:
        bonus_percentage=20
        incentive_status="QUALIFIED"
    elif years_experience>=2 and performance_rating>=3:
        bonus_percentage=10
        incentive_status="QUALIFIED"
    else:
        bonus_percentage=0
        incentive_status="NOT QUALIFIED"
    print(f"=====================================================")
    print(f"             ANNUAL BONUS ASSESSMENT                 ")
    print(f"=====================================================")
    print(f"Tenure Assessed: {years_experience:.1f}")
    print(f"Performance Rank: {performance_rating}/5")
    print(f"-----------------------------------------------------")
    print(f"Incentive Status: {incentive_status}")
    print(f"Bonus Percentage: {bonus_percentage}% Premium")
    print(f"=====================================================")
else:
    print("Invalid Input.Incorrect Performance Rating or Years of Experience")

# %% [markdown]
# ## 📝 Challenge 08: University Admission & Scholarship Checker ⭐⭐⭐
#
# **Task:** Create an academic evaluation system that processes a student's Matric, Intermediate, and Entry Test percentages to determine their university admission eligibility and financial scholarship qualification.
#
# ---
#
# ### 📋 Requirements
#
# 1. **User Inputs:** Prompt the user to enter three percentage marks (Float or Integer):
#    * **Matric Percentage**
#    * **Intermediate Percentage**
#    * **Entry Test Percentage**
# 2. **Data Validation:** Ensure all three inputs sit strictly between `0` and `100`. If any percentage falls outside this range, reject the submission with an error message.
# 3. **Admission Criteria:** A student is marked **Eligible** for admission only if they meet *all* of the following conditions simultaneously:
#    * Entry Test $\ge$ 70% **AND** Intermediate $\ge$ 60% **AND** Matric $\ge$ 60%
# 4. **Scholarship Criteria:** An admitted student qualifies for a **Scholarship** if they hit *all* of these premium benchmarks:
#    * Entry Test $\ge$ 90% **AND** Intermediate $\ge$ 85% **AND** Matric $\ge$ 85%
# 5. **Output Formatting:** Print a clean academic report reflecting their Admission Status (Eligible / Not Eligible) and their Scholarship Status (Scholarship / No Scholarship).
#
# ---
#
# ### 📥 Example Walkthroughs
#
# #### Case A: Full Admission & Scholarship Merit
# * **Inputs:** Matric: `88`, Intermediate: `86`, Entry Test: `92`
# * **Expected Output:**
# ```markdown
# ========================================
#        ACADEMIC EVALUATION REPORT
# ========================================
# Admission Status:   ✅ ELIGIBLE
# Scholarship Status: 🎉 SCHOLARSHIP AWARDED
# ========================================

# %%
matric_percentage=float(input("Enter Your Matric Percentage:"))
intermediate_percentage=float(input("Enter Your Intermediate Percentage:"))
entry_percentage=float(input("Enter Your Entry Test Percentage:"))
if (matric_percentage>=0 and intermediate_percentage>=0 and entry_percentage>=0) and (matric_percentage<=100 and intermediate_percentage<=100 and entry_percentage<=100):
    if entry_percentage>=90 and intermediate_percentage>=85 and matric_percentage>=85:
        admission_status="ELIGIBLE"
        scholarship_status="AWARDED"
    elif entry_percentage>=70 and intermediate_percentage>=60 and matric_percentage>=60:
        admission_status="ELIGIBLE"
        scholarship_status="NOT AWARDED"
    else:
        admission_status="NOT ELIGIBLE"
        scholarship_status="NOT AWARDED"
    print(f"==================================================")
    print(f"            ACADEMIC EVALUATION REPORT            ")
    print(f"==================================================")
    print(f"Admission Status:   {admission_status}")
    print(f"Scholarship Status: {scholarship_status}")
    print(f"==================================================")
else:
    print("Invalid Input.Incorrect Percentage.")

# %% [markdown]
# ## 📝 Challenge 09: Hospital Triage System ⭐⭐⭐
#
# **Task:** Design a clinical emergency assessment tool that processes a patient's age, core body temperature, and blood oxygen saturation level to determine their appropriate triage priority level.
#
# ---
#
# ### 📋 Requirements
#
# 1. **User Inputs:** Prompt the medical staff to enter three patient parameters:
#    * **Age** (Integer/Float)
#    * **Temperature** (Float, in Fahrenheit)
#    * **Oxygen Level** (Integer/Float, as a percentage)
# 2. **Data Validation:** Validate inputs to ensure medical safety:
#    * **Age** must be greater than `0`.
#    * **Temperature** must be within a realistic physiological range (e.g., between `90°F` and `115°F`).
#    * **Oxygen Level** must be between `0` and `100`.
# 3. **Triage Priority Engine:** Categorize the patient using the following hierarchical conditions:
#    * **Emergency:** Oxygen Level $< 90\%$
#    * **High Priority:** Temperature $> 103^\circ\text{F}$ **OR** (Age $> 65$ **AND** Temperature $> 101^\circ\text{F}$)
#    * **Normal:** If none of the critical alert indicators above are triggered.
# 4. **Output Formatting:** Display a medical triage label reflecting the patient's vitals assessment and their final assigned medical priority level.
#
# ---
#
# ### 📥 Example Walkthroughs
#
# #### Case A: Critical Drop in Oxygen
# * **Inputs:** Age: `45`, Temperature: `98.6`, Oxygen Level: `88`
# * **Expected Output:**
# ```markdown
# ========================================
#          CLINICAL TRIAGE REPORT
# ========================================
# Vitals Checked:
#   - Age:             45 Years
#   - Temperature:     98.60°F
#   - Oxygen Sat:      88.00%
# ----------------------------------------
# Triage Status:       🚨 EMERGENCY
# Action Required:     Immediate Medical Attention
# ========================================

# %%
age=int(input("Enter Age of Patient:"))
temp=float(input("Enter Temperature of Patient in Fahrenheit:"))
oxygen_level=float(input('Enter Oxygen Level of PAtient:'))
if age>0 and (temp>=90 and temp<=115) and (oxygen_level>0 and oxygen_level<=100):
    if oxygen_level<=90:
        status="Emergency"
        action="Immediate"
    elif temp>=103 or (age>=65 and temp>=101):
        status="HIGH PRIORITY"
        action="Immediate"
    else:
        status="NORMAL"
        action="General"
    print(f"========================================================")
    print(f"                CLINICAL TRIAGE REPORT                  ")
    print(f"========================================================")
    print(f"Vitals Checked:")
    print(f" -{"Age":<20} {age} Years")
    print(f" -{"Temperature":<20} {temp:.2f}F")
    print(f" -{"Oxygen Sat":<20} {oxygen_level:.2f}%")
    print(f"--------------------------------------------------------")
    print(f"{"Triage Status:":<20} {status}")
    print(f"{"Action Required:":<20} {action} Medical Attention")
    print(f"========================================================")
else:
    print('Invalid Input.Incorrect Age,Temperature or Oxygen Level.')

# %% [markdown]
# ## 📝 Challenge 10: Smart Loan Approval System ⭐⭐⭐⭐⭐
#
# **Task:** Design an automated financial underwriting engine that processes a loan applicant's monthly earnings, credit history rating, employment stability, and outstanding debt obligations to determine their loan approval tier.
#
# ---
#
# ### 📋 Requirements
#
# 1. **User Inputs:** Prompt the loan officer or applicant to provide four parameters:
#    * **Monthly Salary** (Float)
#    * **Credit Score** (Integer, between `300` and `850`)
#    * **Years at Current Job** (Float)
#    * **Existing Monthly Loan Payment (Debt EMI)** (Float)
# 2. **Data Validation:** Validate inputs to protect underwriting accuracy. Reject the evaluation immediately if:
#    * Salary, Job Years, or Existing Payments are **less than 0**.
#    * Credit Score falls **outside the range of 300 to 850**.
# 3. **Underwriting Decision Engine:** Evaluate parameters using a sequential evaluation chain:
#    * **Fully Approved:**
#      * Salary $\ge$ 100,000 **AND** Credit Score $\ge$ 750 **AND** Job Years $\ge$ 2 **AND** Existing Loan Payment $\le$ 30% of Salary.
#    * **Conditionally Approved:** If full approval fails, check if:
#      * Salary $\ge$ 70,000 **AND** Credit Score $\ge$ 650 **AND** Job Years $\ge$ 1 **AND** Existing Loan Payment $\le$ 40% of Salary.
#    * **Rejected:** Triggered if the applicant fails to hit the baseline targets of conditional approval. You must identify and display the **first condition that caused the rejection**.
# 4. **Affordability Metric:** Calculate the **Maximum Affordable EMI** as **35% of their monthly salary**, regardless of their approval outcome.
# 5. **Output Formatting:** Print a professional credit underwriting report detailing applicant metrics, final status, any rejection flags, and maximum EMI thresholds rounded to **2 decimal places**.
#
# ---
#
# ### 📥 Example Walkthroughs
#
# #### Case A: Prime Applicant (Fully Approved)
# * **Inputs:** Salary: `120000`, Credit Score: `780`, Job Years: `3.5`, Existing Payment: `25000`
# * **Expected Output:**
# ```markdown
# ==================================================
#            LOAN UNDERWRITING REPORT
# ==================================================
# APPLICANT METRICS:
#   - Monthly Salary:               Rs.  120,000.00
#   - Credit Score Rank:            780 / 850
#   - Job Stability:                3.50 Years
#   - Current Debt Obligations:     Rs.   25,000.00 (20.83% of income)
# --------------------------------------------------
# DECISION:                         🎉 FULLY APPROVED
# MAXIMUM AFFORDABLE EMI:           Rs.   42,000.00
# ==================================================

# %%
monthly_salary=float(input("Enter Your Monthly Salary:"))
credit_score=int(input("Enter Credit Score(300-850):"))
job_years=float(input("Years at Current Job:"))
existing_loan=float(input("Existing Monthly Loan Payment Amount:"))
if existing_loan>0 and monthly_salary>0:
    existing_loan_percentage=(existing_loan/monthly_salary)*100
else:
    existing_loan_percentage=0
if (monthly_salary>=0 and job_years>=0 and existing_loan>=0) and (credit_score>=300 and credit_score<=850):
    if monthly_salary>=100000 and credit_score>=750 and job_years>=2 and existing_loan_percentage<=30:
        decision="FULLY APPROVED"
        affordable_emi=monthly_salary*(35/100)
    elif monthly_salary>=70000 and credit_score>=650 and job_years>=1 and existing_loan_percentage<=40:
        decision="CONDITIONALLY APPROVED"
        affordable_emi=monthly_salary*(35/100)
    else:
        decision="NOT APPROVED"
        affordable_emi=0
    print(f"=================================================================================")
    print(f"                            LOAN UNDERWRITING REPORT                             ")
    print(f"=================================================================================")
    print(f"APPLICANT METRICS:")
    print(f" -{'Monthly Salary:':<20} Rs. {monthly_salary:.2f}")
    print(f" -{'Credit Score:':<20}   {credit_score}/850")
    print(f" -{'Job Stability:':<20}  {job_years:.2f} Years")
    print(f" -{'Current Debt Obligations:':<20} Rs. {existing_loan:.2f} ({existing_loan_percentage:.2f} of income.)")
    print(f"---------------------------------------------------------------------------------")
    print(f"{'DECISION:':<20}   {decision}")
    print(f"{'MAXIMUM AFFORDABLE EMI:':<20}  Rs. {affordable_emi:.2f}")
    print(f"=================================================================================")
else:
    print(f"Invalid Inputs.Recheck Data")
