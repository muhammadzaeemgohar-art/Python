# %%
import pandas as pd

# %% [markdown]
# # Question 01: Create a Series 🐼
#
# **Task:** Create a Pandas Series containing the elements `'Python'`, `'Statistics'`, `'Mathematics'`, and `'Data Structures'`. Print the resulting Series.
#
# ---
#
# ### 📋 Requirements
#
# 1. **Import Pandas:** Import `pandas as pd`.
# 2. **Series Instantiation:** Use `pd.Series()` passing a standard Python list of topic strings.
# 3. **Display:** Output the generated Series object.
#
# ---
#
# ### 📥 Example Walkthrough
#
# ```text
# 0            Python
# 1        Statistics
# 2       Mathematics
# 3   Data Structures
# dtype: object
# ```
#
# ---
#
# ### 💡 Pandas Concept Tip
#
# > **Key Insight:** A Pandas Series is a 1-dimensional labeled array capable of holding data of any type.
#
# ---
#
# ### 💻 Your Code Solution
#
# ```python
#
# ```

# %% [markdown]
# # Question 02: Series With Custom Index 🐼
#
# **Task:** Create a Pandas Series containing student marks `[85, 92, 76, 88, 69]` using student names `['Ali', 'Sara', 'Ahmed', 'Ayesha', 'Bilal']` as custom index labels.
#
# ---
#
# ### 📋 Requirements
#
# 1. **Data & Index:** Define values `[85, 92, 76, 88, 69]` and corresponding index labels `['Ali', 'Sara', 'Ahmed', 'Ayesha', 'Bilal']`.
# 2. **Instantiation:** Call `pd.Series(data=values, index=names)`.
# 3. **Display:** Print the labeled Series.
#
# ---
#
# ### 📥 Example Walkthrough
#
# ```text
# Ali       85
# Sara      92
# Ahmed     76
# Ayesha    88
# Bilal     69
# dtype: int64
# ```
#
# ---
#
# ### 💡 Pandas Concept Tip
#
# > **Key Insight:** Custom index labels allow key-based value lookups similar to Python dictionaries while maintaining order.
#
# ---
#
# ### 💻 Your Code Solution
#
# ```python
#
# ```

# %% [markdown]
# # Question 03: Access Series Values 🐼
#
# **Task:** Using the labeled Series from Q2, access specific elements via explicit index labels and positional offsets.
#
# ---
#
# ### 📋 Requirements
#
# 1. **Label Lookup:** Print Ali's mark (`series['Ali']`) and Bilal's mark (`series['Bilal']`).
# 2. **Positional Lookup:** Print the first value (`series.iloc[0]` or `series[0]`) and the last value (`series.iloc[-1]`).
#
# ---
#
# ### 📥 Example Walkthrough
#
# ```text
# Ali's marks  : 85
# Bilal's marks: 69
# First value  : 85
# Last value   : 69
# ```
#
# ---
#
# ### 💡 Pandas Concept Tip
#
# > **Key Insight:** Use `.iloc` for explicit positional indexing to avoid ambiguity when working with numeric index labels.
#
# ---
#
# ### 💻 Your Code Solution
#
# ```python
#
# ```

# %% [markdown]
# # Question 04: Create DataFrame 🐼
#
# **Task:** Construct a 2D Pandas DataFrame containing four records with columns `Name`, `Age`, `Department`, and `Marks`.
#
# ---
#
# ### 📋 Requirements
#
# 1. **Dictionary Prep:** Define a dictionary with keys `'Name'`, `'Age'`, `'Department'`, and `'Marks'` mapped to their respective record lists.
# 2. **DataFrame Creation:** Pass the dictionary to `pd.DataFrame()`.
# 3. **Display:** Print the DataFrame.
#
# ---
#
# ### 📥 Example Walkthrough
#
# ```text
#      Name  Age Department  Marks
# 0     Ali   21         DS     85
# 1    Sara   22         CS     92
# 2   Ahmed   20         DS     76
# 3  Ayesha   23         AI     88
# ```
#
# ---
#
# ### 💡 Pandas Concept Tip
#
# > **Key Insight:** A DataFrame is a 2-dimensional tabular structure with row and column labels.
#
# ---
#
# ### 💻 Your Code Solution
#
# ```python
#
# ```

# %% [markdown]
# # Question 05: Series vs DataFrame 🐼
#
# **Task:** Create one 1D Pandas Series (student marks) and one 2D Pandas DataFrame (student names, ages, marks). Print both and state their dimensionality.
#
# ---
#
# ### 📋 Requirements
#
# 1. **Series Creation:** Create a 1D Series of marks.
# 2. **DataFrame Creation:** Create a 2D DataFrame with multiple attributes.
# 3. **Dimensionality Check:** Inspect and print `.ndim` for both structures.
#
# ---
#
# ### 📥 Example Walkthrough
#
# ```text
# 1D Series:
# 0    85
# 1    92
# 2    76
# dtype: int64
# Dimensions: 1
#
# 2D DataFrame:
#    Name  Age  Marks
# 0   Ali   21     85
# 1  Sara   22     92
# 2 Ahmed   20     76
# Dimensions: 2
# ```
#
# ---
#
# ### 💡 Pandas Concept Tip
#
# > **Key Insight:** A Series has 1 dimension (`shape: (n,)`), whereas a DataFrame has 2 dimensions (`shape: (n, m)`).
#
# ---
#
# ### 💻 Your Code Solution
#
# ```python
#
# ```

# %% [markdown]
# # Question 06: Read CSV 📂
#
# **Task:** Create a CSV file named `students.csv` with the main dataset. Then load `students.csv` into a Pandas DataFrame using `pd.read_csv()` and print the output.
#
# ---
#
# ### 📋 Requirements
#
# 1. **CSV Preparation:** Save student records to `students.csv`.
# 2. **Load File:** Read the dataset into a DataFrame using `pd.read_csv('students.csv')`.
# 3. **Display:** Print the loaded DataFrame.
#
# ---
#
# ### 📥 Example Walkthrough
#
# ```text
#     Name  Age       City Department  Marks  Salary
# 0    Ali   21     Lahore         DS     85   70000
# 1   Sara   22  Islamabad         CS     92   85000
# 2  Ahmed   20     Lahore         DS     76   60000
# 3 Ayesha   23    Karachi         AI     88   90000
# ...
# ```
#
# ---
#
# ### 💡 Pandas Concept Tip
#
# > **Key Insight:** `pd.read_csv()` is the primary Pandas tool for reading comma-separated tabular text files.
#
# ---
#
# ### 💻 Your Code Solution
#
# ```python
#
# ```

# %% [markdown]
# # Question 07: Save DataFrame 📂
#
# **Task:** Export your main DataFrame to `students_backup.csv` using `.to_csv()`. Ensure that the DataFrame index is not written to disk.
#
# ---
#
# ### 📋 Requirements
#
# 1. **DataFrame Setup:** Start with the student DataFrame.
# 2. **Export to CSV:** Call `df.to_csv('students_backup.csv', index=False)`.
# 3. **Verification:** Confirm the file is created without an unneeded index column.
#
# ---
#
# ### 📥 Example Walkthrough
#
# ```text
# File saved to 'students_backup.csv' (index=False).
#
# First line of file output:
# Name,Age,City,Department,Marks,Salary
# ```
#
# ---
#
# ### 💡 Pandas Concept Tip
#
# > **Key Insight:** Setting `index=False` in `to_csv()` prevents Pandas from exporting an extra numeric index column (`0,1,2...`) into your CSV file.
#
# ---
#
# ### 💻 Your Code Solution
#
# ```python
#
# ```

# %% [markdown]
# # Question 08: JSON 📂
#
# **Task:** Convert your student DataFrame to a JSON file named `students.json` using `.to_json()`. Then load it back into memory using `pd.read_json()`.
#
# ---
#
# ### 📋 Requirements
#
# 1. **Save JSON:** Export using `df.to_json('students.json', orient='records', indent=4)`.
# 2. **Read JSON:** Load the dataset back with `pd.read_json('students.json')`.
# 3. **Display:** Print the loaded DataFrame.
#
# ---
#
# ### 📥 Example Walkthrough
#
# ```text
# JSON export successful.
#
# Reloaded DataFrame from 'students.json':
#     Name  Age       City Department  Marks  Salary
# 0    Ali   21     Lahore         DS     85   70000
# 1   Sara   22  Islamabad         CS     92   85000
# ...
# ```
#
# ---
#
# ### 💡 Pandas Concept Tip
#
# > **Key Insight:** Specifying `orient='records'` produces an intuitive JSON array of record dictionaries.
#
# ---
#
# ### 💻 Your Code Solution
#
# ```python
#
# ```

# %% [markdown]
# # Question 09: Excel 📂
#
# **Task:** Export your student DataFrame to `students.xlsx` using `.to_excel()`. Then load it back into memory using `pd.read_excel()`.
#
# ---
#
# ### 📋 Requirements
#
# 1. **Save Excel:** Call `df.to_excel('students.xlsx', index=False)`.
# 2. **Read Excel:** Call `pd.read_excel('students.xlsx')`.
# 3. **Display:** Output the reloaded DataFrame.
#
# ---
#
# ### 📥 Example Walkthrough
#
# ```text
# Excel export successful.
#
# Reloaded DataFrame from 'students.xlsx':
#     Name  Age       City Department  Marks  Salary
# 0    Ali   21     Lahore         DS     85   70000
# ...
# ```
#
# ---
#
# ### 💡 Pandas Concept Tip
#
# > **Key Insight:** Exporting to Excel format requires the optional `openpyxl` dependency (`pip install openpyxl`).
#
# ---
#
# ### 💻 Your Code Solution
#
# ```python
#
# ```

# %% [markdown]
# # Question 10: First & Last Records 🔍
#
# **Task:** Using the main student DataFrame, display the first 5 records and the last 3 records.
#
# ---
#
# ### 📋 Requirements
#
# 1. **Head Selection:** Display the top 5 records using `df.head(5)`.
# 2. **Tail Selection:** Display the bottom 3 records using `df.tail(3)`.
#
# ---
#
# ### 📥 Example Walkthrough
#
# ```text
# First 5 Rows (head):
#     Name  Age       City Department  Marks  Salary
# 0    Ali   21     Lahore         DS     85   70000
# 1   Sara   22  Islamabad         CS     92   85000
# 2  Ahmed   20     Lahore         DS     76   60000
# 3 Ayesha   23    Karachi         AI     88   90000
# 4  Bilal   21  Islamabad         CS     69   55000
#
# Last 3 Rows (tail):
#     Name  Age     City Department  Marks  Salary
# 5   Hina   24   Lahore         DS     95   95000
# 6  Usman   22  Karachi         AI     81   75000
# 7   Zain   20   Lahore         CS     73   58000
# ```
#
# ---
#
# ### 💡 Pandas Concept Tip
#
# > **Key Insight:** Use `head()` and `tail()` for quick sanity checks on your dataset structure.
#
# ---
#
# ### 💻 Your Code Solution
#
# ```python
#
# ```

# %% [markdown]
# # Question 11: Dataset Shape 🔍
#
# **Task:** Determine the total number of rows and columns in the main student DataFrame using the `.shape` attribute.
#
# ---
#
# ### 📋 Requirements
#
# 1. **Shape Property:** Access `df.shape`.
# 2. **Unpack Metadata:** Print rows (`df.shape[0]`) and columns (`df.shape[1]`).
#
# ---
#
# ### 📥 Example Walkthrough
#
# ```text
# DataFrame Shape : (8, 6)
# Number of Rows  : 8
# Number of Cols  : 6
# ```
#
# ---
#
# ### 💡 Pandas Concept Tip
#
# > **Key Insight:** The `.shape` attribute returns a tuple formatted as `(rows, columns)`.
#
# ---
#
# ### 💻 Your Code Solution
#
# ```python
#
# ```

# %% [markdown]
# # Question 12: Columns & Index 🔍
#
# **Task:** Print all column header names and inspect the DataFrame row index using `.columns` and `.index`.
#
# ---
#
# ### 📋 Requirements
#
# 1. **Columns Access:** Print `df.columns`.
# 2. **Index Access:** Print `df.index`.
#
# ---
#
# ### 📥 Example Walkthrough
#
# ```text
# Column Names : Index(['Name', 'Age', 'City', 'Department', 'Marks', 'Salary'], dtype='object')
# Row Index    : RangeIndex(start=0, stop=8, step=1)
# ```
#
# ---
#
# ### 💡 Pandas Concept Tip
#
# > **Key Insight:** `df.columns` holds the list-like Index object containing column headers.
#
# ---
#
# ### 💻 Your Code Solution
#
# ```python
#
# ```

# %% [markdown]
# Age            int64
# City          object
# Department    object
# Marks          int64
# Salary         int64
# dtype: object
# ```
#
# ---
#
# ### 💡 Pandas Concept Tip
#
# > **Key Insight:** In Pandas, string columns are typically represented with the `object` (or `string`) dtype.
#
# ---
#
# ### 💻 Your Code Solution
#
# ```python
#
# ```

# %% [markdown]
# # Question 14: Dataset Information 🔍
#
# **Task:** Run `df.info()` on your main DataFrame and identify total entries, column count, non-null value counts, and memory usage.
#
# ---
#
# ### 📋 Requirements
#
# 1. **Info Method:** Execute `df.info()`.
# 2. **Summary:** Note column names, non-null counts, and data types.
#
# ---
#
# ### 📥 Example Walkthrough
#
# ```text
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        8 non-null      object
#  1   Age         8 non-null      int64
#  2   City        8 non-null      object
#  3   Department  8 non-null      object
#  4   Marks       8 non-null      int64
#  5   Salary      8 non-null      int64
# dtypes: int64(3), object(3)
# memory usage: 512.0+ bytes
# ```
#
# ---
#
# ### 💡 Pandas Concept Tip
#
# > **Key Insight:** `info()` provides a comprehensive overview of missing values, column data types, and total memory usage.
#
# ---
#
# ### 💻 Your Code Solution
#
# ```python
#
# ```

# %% [markdown]
# # Question 15: Statistical Summary 🔍
#
# **Task:** Generate numerical summary statistics using `df.describe()` and extract average age, average marks, min/max marks, and average salary.
#
# ---
#
# ### 📋 Requirements
#
# 1. **Describe Call:** Execute `df.describe()`.
# 2. **Target Stats:** Print mean, min, and max metrics for numerical columns.
#
# ---
#
# ### 📥 Example Walkthrough
#
# ```text
# Statistical Summary:
#              Age      Marks        Salary
# count   8.000000   8.000000      8.000000
# mean   21.625000  82.750000  73500.000000
# std     1.407886   9.285934  15042.796092
# min    20.000000  69.000000  55000.000000
# max    24.000000  95.000000  95000.000000
#
# Extracted Values:
# - Average Age    : 21.62
# - Average Marks  : 82.75
# - Minimum Marks  : 69
# - Maximum Marks  : 95
# - Average Salary : 73,500.00
# ```
#
# ---
#
# ### 💡 Pandas Concept Tip
#
# > **Key Insight:** By default, `describe()` summarizes only numeric columns. Pass `include='all'` to inspect object columns as well.
#
# ---
#
# ### 💻 Your Code Solution
#
# ```python
#
# ```

# %% [markdown]
# # Question 16: Unique Values 🔍
#
# **Task:** Count the number of distinct unique values in the `City`, `Department`, and `Age` columns using `nunique()`.
#
# ---
#
# ### 📋 Requirements
#
# 1. **Nunique Method:** Call `df[['City', 'Department', 'Age']].nunique()` or individual `df['col'].nunique()`.
# 2. **Display:** Print the count of unique values per column.
#
# ---
#
# ### 📥 Example Walkthrough
#
# ```text
# Unique Cities       : 3
# Unique Departments  : 3
# Unique Ages         : 5
# ```
#
# ---
#
# ### 💡 Pandas Concept Tip
#
# > **Key Insight:** `nunique()` excludes missing (`NaN`) values by default when counting distinct values.
#
# ---
#
# ### 💻 Your Code Solution
#
# ```python
#
# ```

# %% [markdown]
# # Question 17: Value Counts 🔍
#
# **Task:** Find the frequency count of students belonging to each `City` and `Department` using `value_counts()`.
#
# ---
#
# ### 📋 Requirements
#
# 1. **City Frequency:** Call `df['City'].value_counts()`.
# 2. **Department Frequency:** Call `df['Department'].value_counts()`.
# 3. **Display:** Print both distribution counts.
#
# ---
#
# ### 📥 Example Walkthrough
#
# ```text
# City Value Counts:
# Lahore       4
# Islamabad    2
# Karachi      2
# Name: City, dtype: int64
#
# Department Value Counts:
# DS    3
# CS    3
# AI    2
# Name: Department, dtype: int64
# ```
#
# ---
#
# ### 💡 Pandas Concept Tip
#
# > **Key Insight:** `value_counts()` returns counts sorted in descending order, making it quick to spot the most frequent categories.
#
# ---
#
# ### 💻 Your Code Solution
#
# ```python
#
# ```

# %% [markdown]
# # Question 18: Select One Column 🎯
#
# **Task:** Extract and print only the `Name` column from the student DataFrame as a Pandas Series.
#
# ---
#
# ### 📋 Requirements
#
# 1. **Column Selection:** Access the column using bracket notation `df['Name']` or attribute access `df.Name`.
# 2. **Display:** Print the resulting Series object.
#
# ---
#
# ### 📥 Example Walkthrough
#
# ```text
# 0       Ali
# 1      Sara
# 2     Ahmed
# 3    Ayesha
# 4     Bilal
# 5      Hina
# 6     Usman
# 7      Zain
# Name: Name, dtype: object
# ```
#
# ---
#
# ### 💡 Pandas Concept Tip
#
# > **Key Insight:** Selecting a single column from a DataFrame returns a 1D Pandas Series object.
#
# ---
#
# ### 💻 Your Code Solution
#
# ```python
#
# ```

# %% [markdown]
# # Question 19: Select Multiple Columns 🎯
#
# **Task:** Select and display a subset DataFrame containing only the `Name`, `Department`, and `Marks` columns.
#
# ---
#
# ### 📋 Requirements
#
# 1. **Multiple Selection:** Pass a list of column names `df[['Name', 'Department', 'Marks']]`.
# 2. **Display:** Print the resulting 2D DataFrame subset.
#
# ---
#
# ### 📥 Example Walkthrough
#
# ```text
#      Name Department  Marks
# 0     Ali         DS     85
# 1    Sara         CS     92
# 2   Ahmed         DS     76
# 3  Ayesha         AI     88
# 4   Bilal         CS     69
# 5    Hina         DS     95
# 6   Usman         AI     81
# 7    Zain         CS     73
# ```
#
# ---
#
# ### 💡 Pandas Concept Tip
#
# > **Key Insight:** Passing a double bracket `df[['col1', 'col2']]` selects multiple columns and returns a DataFrame.
#
# ---
#
# ### 💻 Your Code Solution
#
# ```python
#
# ```

# %% [markdown]
# # Question 20: .loc[] 🎯
#
# **Task:** Demonstrate label-based indexing using `.loc[]` to select the first student's complete record, students from index 2 to 5, and only `Name` & `Marks` for index 1 to 4.
#
# ---
#
# ### 📋 Requirements
#
# 1. **Single Record:** Access row label `0` using `df.loc[0]`.
# 2. **Row Slice:** Access row labels `2` through `5` using `df.loc[2:5]`.
# 3. **Row & Column Slice:** Access index `1:4` and columns `['Name', 'Marks']` using `df.loc[1:4, ['Name', 'Marks']]`.
#
# ---
#
# ### 📥 Example Walkthrough
#
# ```text
# First Student Record (.loc[0]):
# Name             Ali
# Age               21
# City          Lahore
# Department        DS
# Marks             85
# Salary         70000
# Name: 0, dtype: object
#
# Students Index 2 to 5 (.loc[2:5]):
#      Name  Age       City Department  Marks  Salary
# 2   Ahmed   20     Lahore         DS     76   60000
# 3  Ayesha   23    Karachi         AI     88   90000
# 4   Bilal   21  Islamabad         CS     69   55000
# 5    Hina   24     Lahore         DS     95   95000
#
# Name & Marks for Index 1-4 (.loc[1:4, ['Name', 'Marks']]):
#      Name  Marks
# 1    Sara     92
# 2   Ahmed     76
# 3  Ayesha     88
# 4   Bilal     69
# ```
#
# ---
#
# ### 💡 Pandas Concept Tip
#
# > **Key Insight:** In `.loc[]`, row slices are **inclusive** of the end boundary (e.g., `loc[2:5]` includes row 5).
#
# ---
#
# ### 💻 Your Code Solution
#
# ```python
#
# ```

# %% [markdown]
# # Question 21: .iloc[] 🎯
#
# **Task:** Demonstrate position-based indexing using `.iloc[]` to select the first record, rows at positions 2 to 5, and Name/Marks columns (positions 0 and 4) for row positions 1 to 4.
#
# ---
#
# ### 📋 Requirements
#
# 1. **Single Position:** Access row position `0` using `df.iloc[0]`.
# 2. **Position Slice:** Access rows `2:6` (to get 2 to 5) using `df.iloc[2:6]`.
# 3. **Position Row/Col Slice:** Access rows `1:5` and columns `[0, 4]` using `df.iloc[1:5, [0, 4]]`.
#
# ---
#
# ### 📥 Example Walkthrough
#
# ```text
# First Student Position (.iloc[0]):
# Name             Ali
# Age               21
# City          Lahore
# Department        DS
# Marks             85
# Salary         70000
# Name: 0, dtype: object
#
# Position Slice 2 to 5 (.iloc[2:6]):
#      Name  Age       City Department  Marks  Salary
# 2   Ahmed   20     Lahore         DS     76   60000
# 3  Ayesha   23    Karachi         AI     88   90000
# 4   Bilal   21  Islamabad         CS     69   55000
# 5    Hina   24     Lahore         DS     95   95000
#
# Name & Marks Position Slice (.iloc[1:5, [0, 4]]):
#      Name  Marks
# 1    Sara     92
# 2   Ahmed     76
# 3  Ayesha     88
# 4   Bilal     69
# ```
#
# ---
#
# ### 💡 Pandas Concept Tip
#
# > **Key Insight:** In `.iloc[]`, integer slices follow Python standard convention and are **exclusive** of the end boundary.
#
# ---
#
# ### 💻 Your Code Solution
#
# ```python
#
# ```

# %% [markdown]
# # Question 22: .loc vs .iloc 🎯
#
# **Task:** Create a small example on a DataFrame with custom string row index labels (e.g., `['r1', 'r2', 'r3']`) to clearly illustrate the difference between label-based `.loc[]` and integer position-based `.iloc[]`.
#
# ---
#
# ### 📋 Requirements
#
# 1. **Custom Index Setup:** Re-index a small subset with string labels `['r1', 'r2', 'r3']`.
# 2. **Label Lookup (.loc):** Use `df.loc['r2']` to retrieve by label.
# 3. **Position Lookup (.iloc):** Use `df.iloc[1]` to retrieve by offset position.
# 4. **Explanation:** Document why `.loc[]` fails on integer positions when labels are strings and vice versa.
#
# ---
#
# ### 📥 Example Walkthrough
#
# ```text
# Sample Labeled DataFrame:
#     Name  Marks
# r1   Ali     85
# r2  Sara     92
# r3 Ahmed     76
#
# Label Selection (.loc['r2']):
# Name     Sara
# Marks      92
# Name: r2, dtype: object
#
# Position Selection (.iloc[1]):
# Name     Sara
# Marks      92
# Name: r2, dtype: object
#
# Key Takeaway:
# .loc uses explicit row/column labels.
# .iloc uses 0-based integer position offsets.
# ```
#
# ---
#
# ### 💡 Pandas Concept Tip
#
# > **Key Insight:** Always prefer `.loc` for key labels and `.iloc` for integer positional slicing to keep code unambiguous.
#
# ---
#
# ### 💻 Your Code Solution
#
# ```python
#
# ```

# %% [markdown]
# # Question 23: Marks Filter 🔎
#
# **Task:** Filter and display all students who scored strictly more than 80 marks.
#
# ---
#
# ### 📋 Requirements
#
# 1. **Boolean Mask:** Create condition `df['Marks'] > 80`.
# 2. **Filter Application:** Apply `df[df['Marks'] > 80]`.
# 3. **Display:** Print the filtered student subset.
#
# ---
#
# ### 📥 Example Walkthrough
#
# ```text
#     Name  Age       City Department  Marks  Salary
# 0    Ali   21     Lahore         DS     85   70000
# 1   Sara   22  Islamabad         CS     92   85000
# 3 Ayesha   23    Karachi         AI     88   90000
# 5   Hina   24     Lahore         DS     95   95000
# 6  Usman   22    Karachi         AI     81   75000
# ```
#
# ---
#
# ### 💡 Pandas Concept Tip
#
# > **Key Insight:** Boolean filtering evaluates a condition across all rows and returns rows where the result is `True`.
#
# ---
#
# ### 💻 Your Code Solution
#
# ```python
#
# ```

# %% [markdown]
# # Question 24: Age Filter 🔎
#
# **Task:** Filter and display all students whose age is greater than or equal to 22.
#
# ---
#
# ### 📋 Requirements
#
# 1. **Condition:** Evaluate `df['Age'] >= 22`.
# 2. **Filter:** Apply `df[df['Age'] >= 22]`.
# 3. **Display:** Print matching records.
#
# ---
#
# ### 📥 Example Walkthrough
#
# ```text
#     Name  Age       City Department  Marks  Salary
# 1   Sara   22  Islamabad         CS     92   85000
# 3 Ayesha   23    Karachi         AI     88   90000
# 5   Hina   24     Lahore         DS     95   95000
# 6  Usman   22    Karachi         AI     81   75000
# ```
#
# ---
#
# ### 💡 Pandas Concept Tip
#
# > **Key Insight:** Relational comparison operators (`>`, `>=`, `<`, `<=`, `==`, `!=`) work vectorized across DataFrame columns.
#
# ---
#
# ### 💻 Your Code Solution
#
# ```python
#
# ```

# %% [markdown]
# # Question 25: Multiple Conditions 🔎
#
# **Task:** Filter students who satisfy both conditions: `Age > 20` AND `Marks > 80`.
#
# ---
#
# ### 📋 Requirements
#
# 1. **Combined Mask:** Use the bitwise AND operator `(df['Age'] > 20) & (df['Marks'] > 80)`.
# 2. **Filtering:** Apply `df[(df['Age'] > 20) & (df['Marks'] > 80)]`.
# 3. **Display:** Output matching records.
#
# ---
#
# ### 📥 Example Walkthrough
#
# ```text
#     Name  Age       City Department  Marks  Salary
# 0    Ali   21     Lahore         DS     85   70000
# 1   Sara   22  Islamabad         CS     92   85000
# 3 Ayesha   23    Karachi         AI     88   90000
# 5   Hina   24     Lahore         DS     95   95000
# 6  Usman   22    Karachi         AI     81   75000
# ```
#
# ---
#
# ### 💡 Pandas Concept Tip
#
# > **Key Insight:** Always wrap individual condition expressions in parentheses when combining them with `&` or `|`.
#
# ---
#
# ### 💻 Your Code Solution
#
# ```python
#
# ```

# %% [markdown]
# # Question 26: City + Marks 🔎
#
# **Task:** Find all students who belong to `City == 'Lahore'` AND scored `Marks > 80`.
#
# ---
#
# ### 📋 Requirements
#
# 1. **Combined Condition:** Use `(df['City'] == 'Lahore') & (df['Marks'] > 80)`.
# 2. **Filter Execution:** Execute `df[(df['City'] == 'Lahore') & (df['Marks'] > 80)]`.
# 3. **Display:** Output filtered records.
#
# ---
#
# ### 📥 Example Walkthrough
#
# ```text
#    Name  Age    City Department  Marks  Salary
# 0   Ali   21  Lahore         DS     85   70000
# 5  Hina   24  Lahore         DS     95   95000
# ```
#
# ---
#
# ### 💡 Pandas Concept Tip
#
# > **Key Insight:** Pandas uses bitwise operators (`&` for AND, `|` for OR, `~` for NOT) instead of standard Python keywords.
#
# ---
#
# ### 💻 Your Code Solution
#
# ```python
#
# ```

# %% [markdown]
# # Question 27: OR Condition 🔎
#
# **Task:** Find all students who are either from `Lahore` OR from `Karachi` using the bitwise OR operator (`|`).
#
# ---
#
# ### 📋 Requirements
#
# 1. **OR Mask:** Construct `(df['City'] == 'Lahore') | (df['City'] == 'Karachi')`.
# 2. **Filter:** Apply `df[(df['City'] == 'Lahore') | (df['City'] == 'Karachi')]`.
# 3. **Display:** Print matching records.
#
# ---
#
# ### 📥 Example Walkthrough
#
# ```text
#      Name  Age     City Department  Marks  Salary
# 0     Ali   21   Lahore         DS     85   70000
# 2   Ahmed   20   Lahore         DS     76   60000
# 3  Ayesha   23  Karachi         AI     88   90000
# 5    Hina   24   Lahore         DS     95   95000
# 6   Usman   22  Karachi         AI     81   75000
# 7    Zain   20   Lahore         CS     73   58000
# ```
#
# ---
#
# ### 💡 Pandas Concept Tip
#
# > **Key Insight:** The `|` operator matches rows where at least one condition evaluates to `True`.
#
# ---
#
# ### 💻 Your Code Solution
#
# ```python
#
# ```

# %% [markdown]
# # Question 28: isin() 🔎
#
# **Task:** Simplify categorical multi-value matching using `.isin()` to find students from `Lahore` or `Islamabad`.
#
# ---
#
# ### 📋 Requirements
#
# 1. **isin Selection:** Call `df[df['City'].isin(['Lahore', 'Islamabad'])]`.
# 2. **Display:** Print matching records.
#
# ---
#
# ### 📥 Example Walkthrough
#
# ```text
#     Name  Age       City Department  Marks  Salary
# 0    Ali   21     Lahore         DS     85   70000
# 1   Sara   22  Islamabad         CS     92   85000
# 2  Ahmed   20     Lahore         DS     76   60000
# 4  Bilal   21  Islamabad         CS     69   55000
# 5   Hina   24     Lahore         DS     95   95000
# 7   Zain   20     Lahore         CS     73   58000
# ```
#
# ---
#
# ### 💡 Pandas Concept Tip
#
# > **Key Insight:** `.isin([list])` is much cleaner than chaining multiple `==` conditions with OR operators.
#
# ---
#
# ### 💻 Your Code Solution
#
# ```python
#
# ```

# %% [markdown]
# # Question 29: between() 🔎
#
# **Task:** Find students whose marks fall within the inclusive range of 70 to 90 using `.between()`.
#
# ---
#
# ### 📋 Requirements
#
# 1. **Between Method:** Call `df[df['Marks'].between(70, 90)]`.
# 2. **Display:** Output matching records.
#
# ---
#
# ### 📥 Example Walkthrough
#
# ```text
#     Name  Age     City Department  Marks  Salary
# 0    Ali   21   Lahore         DS     85   70000
# 2  Ahmed   20   Lahore         DS     76   60000
# 3 Ayesha   23  Karachi         AI     88   90000
# 6  Usman   22  Karachi         AI     81   75000
# 7   Zain   20   Lahore         CS     73   58000
# ```
#
# ---
#
# ### 💡 Pandas Concept Tip
#
# > **Key Insight:** By default, `.between(lower, upper)` is inclusive of both `lower` and `upper` boundary values.
#
# ---
#
# ### 💻 Your Code Solution
#
# ```python
#
# ```

# %% [markdown]
# # Question 30: query() 🔎
#
# **Task:** Perform string expression filtering using `.query()` to locate students with `Age > 21` and `Marks > 80`.
#
# ---
#
# ### 📋 Requirements
#
# 1. **Query Execution:** Call `df.query('Age > 21 and Marks > 80')`.
# 2. **Display:** Print matching records.
#
# ---
#
# ### 📥 Example Walkthrough
#
# ```text
#     Name  Age       City Department  Marks  Salary
# 1   Sara   22  Islamabad         CS     92   85000
# 3 Ayesha   23    Karachi         AI     88   90000
# 5   Hina   24     Lahore         DS     95   95000
# 6  Usman   22    Karachi         AI     81   75000
# ```
#
# ---
#
# ### 💡 Pandas Concept Tip
#
# > **Key Insight:** `.query()` allows writing readable boolean filter expressions using standard string syntax and standard words (`and`, `or`, `not`).
#
# ---
#
# ### 💻 Your Code Solution
#
# ```python
#
# ```
